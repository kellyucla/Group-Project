# %% [markdown]
# **Education Attainment in San Diego County**
#
# This notebook takes a look at the level of educational attainment and employment in San Deigo County by people between the ages of 25 to 64.
#
# Kelly Banh

# %%
import pandas as pd

# to read and visualize spatial data
import geopandas as gpd

# to provide basemaps 
import contextily as ctx

# to give more power to your figures (plots)
import matplotlib.pyplot as plt

# %%
edu = gpd.read_file('eduemploy.geojson')

# %%
edu.shape
# Out:
# (628, 61)

# %%
edu.head()
# Out:
#                 geoid                              name  B23006001  \
# 0  14000US06073000100     Census Tract 1, San Diego, CA     1431.0
# 1  14000US06073000201  Census Tract 2.01, San Diego, CA     1025.0
# 2  14000US06073000202  Census Tract 2.02, San Diego, CA     2972.0
# 3  14000US06073000300     Census Tract 3, San Diego, CA     3359.0
# 4  14000US06073000400     Census Tract 4, San Diego, CA     2720.0
#
#    B23006001, Error  B23006002  B23006002, Error  B23006003  B23006003, Error  \
# 0             234.0       70.0              78.0       53.0              75.0
# 1             132.0        0.0              12.0        0.0              12.0
# 2             269.0       43.0              54.0        0.0              12.0
# 3             370.0       79.0              83.0       64.0              78.0
# 4             377.0       55.0              35.0        0.0              12.0
#
#    B23006004  B23006004, Error  ...  B23006025, Error  B23006026  \
# 0        0.0              12.0  ...              10.0      914.0
# 1        0.0              12.0  ...              12.0      747.0
# 2        0.0              12.0  ...              47.0     1641.0
# 3        0.0              17.0  ...              17.0     1869.0
# 4        0.0              12.0  ...              31.0     1398.0
#
#    B23006026, Error  B23006027  B23006027, Error  B23006028  B23006028, Error  \
# 0             170.0      898.0             162.0       16.0              24.0
# 1             138.0      711.0             134.0       36.0              35.0
# 2             347.0     1641.0             347.0        0.0              12.0
# 3             306.0     1790.0             316.0       79.0             101.0
# 4             290.0     1259.0             264.0      139.0             104.0
#
#    B23006029  B23006029, Error  \
# 0      205.0              84.0
# 1      120.0              59.0
# 2      236.0             145.0
# 3      219.0              92.0
# 4       81.0              74.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-117.19490 32.75278, -117.1947...
# 1  MULTIPOLYGON (((-117.17887 32.75765, -117.1779...
# 2  MULTIPOLYGON (((-117.18404 32.74571, -117.1838...
# 3  MULTIPOLYGON (((-117.16864 32.74897, -117.1684...
# 4  MULTIPOLYGON (((-117.17087 32.75865, -117.1701...
#
# [5 rows x 61 columns]

# %%
edu.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# overwriting default settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
edu.sample()
# Out:
#                  geoid                            name  B23006001  \
# 96  14000US06073004800  Census Tract 48, San Diego, CA     2386.0
#
#     B23006001, Error  B23006002  B23006002, Error  B23006003  \
# 96             314.0      894.0             234.0      686.0
#
#     B23006003, Error  B23006004  B23006004, Error  B23006005  \
# 96             203.0        0.0              12.0      686.0
#
#     B23006005, Error  B23006006  B23006006, Error  B23006007  \
# 96             203.0      647.0             191.0       39.0
#
#     B23006007, Error  B23006008  B23006008, Error  B23006009  \
# 96              43.0      208.0              88.0      845.0
#
#     B23006009, Error  B23006010  B23006010, Error  B23006011  \
# 96             211.0      633.0             193.0        0.0
#
#     B23006011, Error  B23006012  B23006012, Error  B23006013  \
# 96              12.0      633.0             193.0      575.0
#
#     B23006013, Error  B23006014  B23006014, Error  B23006015  \
# 96             169.0       58.0              63.0      212.0
#
#     B23006015, Error  B23006016  B23006016, Error  B23006017  \
# 96              97.0      516.0             165.0      449.0
#
#     B23006017, Error  B23006018  B23006018, Error  B23006019  \
# 96             143.0        0.0              12.0      449.0
#
#     B23006019, Error  B23006020  B23006020, Error  B23006021  \
# 96             143.0      427.0             144.0       22.0
#
#     B23006021, Error  B23006022  B23006022, Error  B23006023  \
# 96              34.0       67.0              51.0      131.0
#
#     B23006023, Error  B23006024  B23006024, Error  B23006025  \
# 96              68.0      123.0              67.0        0.0
#
#     B23006025, Error  B23006026  B23006026, Error  B23006027  \
# 96              12.0      123.0              67.0      113.0
#
#     B23006027, Error  B23006028  B23006028, Error  B23006029  \
# 96              67.0       10.0              16.0        8.0
#
#     B23006029, Error                                           geometry
# 96              11.0  MULTIPOLYGON (((-117.14246 32.71157, -117.1420...

# %%
# looking at the data types
edu.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 628 entries, 0 to 627
# Data columns (total 61 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             628 non-null    object
#  1   name              628 non-null    object
#  2   B23006001         628 non-null    float64
#  3   B23006001, Error  628 non-null    float64
#  4   B23006002         628 non-null    float64
#  5   B23006002, Error  628 non-null    float64
#  6   B23006003         628 non-null    float64
#  7   B23006003, Error  628 non-null    float64
#  8   B23006004         628 non-null    float64
#  9   B23006004, Error  628 non-null    float64
#  10  B23006005         628 non-null    float64
#  11  B23006005, Error  628 non-null    float64
#  12  B23006006         628 non-null    float64
#  13  B23006006, Error  628 non-null    float64
#  14  B23006007         628 non-null    float64
#  15  B23006007, Error  628 non-null    float64
#  16  B23006008         628 non-null    float64
#  17  B23006008, Error  628 non-null    float64
#  18  B23006009         628 non-null    float64
#  19  B23006009, Error  628 non-null    float64
#  20  B23006010         628 non-null    float64
#  21  B23006010, Error  628 non-null    float64
#  22  B23006011         628 non-null    float64
#  23  B23006011, Error  628 non-null    float64
#  24  B23006012         628 non-null    float64
#  25  B23006012, Error  628 non-null    float64
#  26  B23006013         628 non-null    float64
#  27  B23006013, Error  628 non-null    float64
#  28  B23006014         628 non-null    float64
#  29  B23006014, Error  628 non-null    float64
#  30  B23006015         628 non-null    float64
#  31  B23006015, Error  628 non-null    float64
#  32  B23006016         628 non-null    float64
#  33  B23006016, Error  628 non-null    float64
#  34  B23006017         628 non-null    float64
#  35  B23006017, Error  628 non-null    float64
#  36  B23006018         628 non-null    float64
#  37  B23006018, Error  628 non-null    float64
#  38  B23006019         628 non-null    float64
#  39  B23006019, Error  628 non-null    float64
#  40  B23006020         628 non-null    float64
#  41  B23006020, Error  628 non-null    float64
#  42  B23006021         628 non-null    float64
#  43  B23006021, Error  628 non-null    float64
#  44  B23006022         628 non-null    float64
#  45  B23006022, Error  628 non-null    float64
#  46  B23006023         628 non-null    float64
#  47  B23006023, Error  628 non-null    float64
#  48  B23006024         628 non-null    float64
#  49  B23006024, Error  628 non-null    float64
#  50  B23006025         628 non-null    float64
#  51  B23006025, Error  628 non-null    float64
#  52  B23006026         628 non-null    float64
#  53  B23006026, Error  628 non-null    float64
#  54  B23006027         628 non-null    float64
#  55  B23006027, Error  628 non-null    float64
#  56  B23006028         628 non-null    float64
#  57  B23006028, Error  628 non-null    float64
#  58  B23006029         628 non-null    float64
#  59  B23006029, Error  628 non-null    float64
#  60  geometry          628 non-null    geometry
# dtypes: float64(58), geometry(1), object(2)
# memory usage: 299.4+ KB

# %%
edu.geoid.head()
# Out:
# 0    14000US06073000100
# 1    14000US06073000201
# 2    14000US06073000202
# 3    14000US06073000300
# 4    14000US06073000400
# Name: geoid, dtype: object

# %%
# check the data again
edu.head()
# Out:
#                 geoid                              name  B23006001  \
# 0  14000US06073000100     Census Tract 1, San Diego, CA     1431.0
# 1  14000US06073000201  Census Tract 2.01, San Diego, CA     1025.0
# 2  14000US06073000202  Census Tract 2.02, San Diego, CA     2972.0
# 3  14000US06073000300     Census Tract 3, San Diego, CA     3359.0
# 4  14000US06073000400     Census Tract 4, San Diego, CA     2720.0
#
#    B23006001, Error  B23006002  B23006002, Error  B23006003  B23006003, Error  \
# 0             234.0       70.0              78.0       53.0              75.0
# 1             132.0        0.0              12.0        0.0              12.0
# 2             269.0       43.0              54.0        0.0              12.0
# 3             370.0       79.0              83.0       64.0              78.0
# 4             377.0       55.0              35.0        0.0              12.0
#
#    B23006004  B23006004, Error  B23006005  B23006005, Error  B23006006  \
# 0        0.0              12.0       53.0              75.0       53.0
# 1        0.0              12.0        0.0              12.0        0.0
# 2        0.0              12.0        0.0              12.0        0.0
# 3        0.0              17.0       64.0              78.0       64.0
# 4        0.0              12.0        0.0              12.0        0.0
#
#    B23006006, Error  B23006007  B23006007, Error  B23006008  B23006008, Error  \
# 0              75.0        0.0              12.0       17.0              24.0
# 1              12.0        0.0              12.0        0.0              12.0
# 2              12.0        0.0              12.0       43.0              54.0
# 3              78.0        0.0              17.0       15.0              24.0
# 4              12.0        0.0              12.0       55.0              35.0
#
#    B23006009  B23006009, Error  B23006010  B23006010, Error  B23006011  \
# 0       49.0              36.0       40.0              26.0        0.0
# 1       53.0              37.0       53.0              37.0        0.0
# 2      224.0             132.0      205.0             124.0        0.0
# 3      171.0             115.0      135.0             110.0        0.0
# 4      257.0             148.0      210.0             146.0        0.0
#
#    B23006011, Error  B23006012  B23006012, Error  B23006013  B23006013, Error  \
# 0              12.0       40.0              26.0       40.0              26.0
# 1              12.0       53.0              37.0       53.0              37.0
# 2              12.0      205.0             124.0      205.0             124.0
# 3              17.0      135.0             110.0      135.0             110.0
# 4              12.0      210.0             146.0      210.0             146.0
#
#    B23006014  B23006014, Error  B23006015  B23006015, Error  B23006016  \
# 0        0.0              12.0        9.0              15.0      186.0
# 1        0.0              12.0        0.0              12.0      105.0
# 2        0.0              12.0       19.0              32.0      778.0
# 3        0.0              17.0       36.0              27.0     1021.0
# 4        0.0              12.0       47.0              39.0      902.0
#
#    B23006016, Error  B23006017  B23006017, Error  B23006018  B23006018, Error  \
# 0              73.0      138.0              69.0        0.0              12.0
# 1              46.0       82.0              41.0        0.0              12.0
# 2             213.0      638.0             179.0        0.0              12.0
# 3             234.0      812.0             210.0        0.0              17.0
# 4             327.0      769.0             306.0       28.0              45.0
#
#    B23006019  B23006019, Error  B23006020  B23006020, Error  B23006021  \
# 0      138.0              69.0      127.0              66.0       11.0
# 1       82.0              41.0       82.0              41.0        0.0
# 2      638.0             179.0      638.0             179.0        0.0
# 3      812.0             210.0      772.0             200.0       40.0
# 4      741.0             308.0      677.0             293.0       64.0
#
#    B23006021, Error  B23006022  B23006022, Error  B23006023  B23006023, Error  \
# 0              17.0       48.0              35.0     1126.0             188.0
# 1              12.0       23.0              22.0      867.0             135.0
# 2              12.0      140.0              78.0     1927.0             362.0
# 3              45.0      209.0             124.0     2088.0             315.0
# 4              75.0      133.0             106.0     1506.0             277.0
#
#    B23006024  B23006024, Error  B23006025  B23006025, Error  B23006026  \
# 0      921.0             170.0        7.0              10.0      914.0
# 1      747.0             138.0        0.0              12.0      747.0
# 2     1691.0             346.0       50.0              47.0     1641.0
# 3     1869.0             306.0        0.0              17.0     1869.0
# 4     1425.0             296.0       27.0              31.0     1398.0
#
#    B23006026, Error  B23006027  B23006027, Error  B23006028  B23006028, Error  \
# 0             170.0      898.0             162.0       16.0              24.0
# 1             138.0      711.0             134.0       36.0              35.0
# 2             347.0     1641.0             347.0        0.0              12.0
# 3             306.0     1790.0             316.0       79.0             101.0
# 4             290.0     1259.0             264.0      139.0             104.0
#
#    B23006029  B23006029, Error  \
# 0      205.0              84.0
# 1      120.0              59.0
# 2      236.0             145.0
# 3      219.0              92.0
# 4       81.0              74.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-117.19490 32.75278, -117.1947...
# 1  MULTIPOLYGON (((-117.17887 32.75765, -117.1779...
# 2  MULTIPOLYGON (((-117.18404 32.74571, -117.1838...
# 3  MULTIPOLYGON (((-117.16864 32.74897, -117.1684...
# 4  MULTIPOLYGON (((-117.17087 32.75865, -117.1701...

# %%
# drop the row with index 0 (i.e. the first row)
edu = edu.drop([0])

# %%
# check to see if it has been deleted
edu.head()
# Out:
#                 geoid                              name  B23006001  \
# 1  14000US06073000201  Census Tract 2.01, San Diego, CA     1025.0
# 2  14000US06073000202  Census Tract 2.02, San Diego, CA     2972.0
# 3  14000US06073000300     Census Tract 3, San Diego, CA     3359.0
# 4  14000US06073000400     Census Tract 4, San Diego, CA     2720.0
# 5  14000US06073000500     Census Tract 5, San Diego, CA     2195.0
#
#    B23006001, Error  B23006002  B23006002, Error  B23006003  B23006003, Error  \
# 1             132.0        0.0              12.0        0.0              12.0
# 2             269.0       43.0              54.0        0.0              12.0
# 3             370.0       79.0              83.0       64.0              78.0
# 4             377.0       55.0              35.0        0.0              12.0
# 5             198.0       43.0              40.0       35.0              37.0
#
#    B23006004  B23006004, Error  B23006005  B23006005, Error  B23006006  \
# 1        0.0              12.0        0.0              12.0        0.0
# 2        0.0              12.0        0.0              12.0        0.0
# 3        0.0              17.0       64.0              78.0       64.0
# 4        0.0              12.0        0.0              12.0        0.0
# 5        0.0              12.0       35.0              37.0       35.0
#
#    B23006006, Error  B23006007  B23006007, Error  B23006008  B23006008, Error  \
# 1              12.0        0.0              12.0        0.0              12.0
# 2              12.0        0.0              12.0       43.0              54.0
# 3              78.0        0.0              17.0       15.0              24.0
# 4              12.0        0.0              12.0       55.0              35.0
# 5              37.0        0.0              12.0        8.0              14.0
#
#    B23006009  B23006009, Error  B23006010  B23006010, Error  B23006011  \
# 1       53.0              37.0       53.0              37.0        0.0
# 2      224.0             132.0      205.0             124.0        0.0
# 3      171.0             115.0      135.0             110.0        0.0
# 4      257.0             148.0      210.0             146.0        0.0
# 5      219.0              99.0      171.0              84.0        0.0
#
#    B23006011, Error  B23006012  B23006012, Error  B23006013  B23006013, Error  \
# 1              12.0       53.0              37.0       53.0              37.0
# 2              12.0      205.0             124.0      205.0             124.0
# 3              17.0      135.0             110.0      135.0             110.0
# 4              12.0      210.0             146.0      210.0             146.0
# 5              12.0      171.0              84.0      171.0              84.0
#
#    B23006014  B23006014, Error  B23006015  B23006015, Error  B23006016  \
# 1        0.0              12.0        0.0              12.0      105.0
# 2        0.0              12.0       19.0              32.0      778.0
# 3        0.0              17.0       36.0              27.0     1021.0
# 4        0.0              12.0       47.0              39.0      902.0
# 5        0.0              12.0       48.0              49.0      626.0
#
#    B23006016, Error  B23006017  B23006017, Error  B23006018  B23006018, Error  \
# 1              46.0       82.0              41.0        0.0              12.0
# 2             213.0      638.0             179.0        0.0              12.0
# 3             234.0      812.0             210.0        0.0              17.0
# 4             327.0      769.0             306.0       28.0              45.0
# 5             174.0      513.0             162.0       10.0              16.0
#
#    B23006019  B23006019, Error  B23006020  B23006020, Error  B23006021  \
# 1       82.0              41.0       82.0              41.0        0.0
# 2      638.0             179.0      638.0             179.0        0.0
# 3      812.0             210.0      772.0             200.0       40.0
# 4      741.0             308.0      677.0             293.0       64.0
# 5      503.0             161.0      469.0             163.0       34.0
#
#    B23006021, Error  B23006022  B23006022, Error  B23006023  B23006023, Error  \
# 1              12.0       23.0              22.0      867.0             135.0
# 2              12.0      140.0              78.0     1927.0             362.0
# 3              45.0      209.0             124.0     2088.0             315.0
# 4              75.0      133.0             106.0     1506.0             277.0
# 5              26.0      113.0              64.0     1307.0             187.0
#
#    B23006024  B23006024, Error  B23006025  B23006025, Error  B23006026  \
# 1      747.0             138.0        0.0              12.0      747.0
# 2     1691.0             346.0       50.0              47.0     1641.0
# 3     1869.0             306.0        0.0              17.0     1869.0
# 4     1425.0             296.0       27.0              31.0     1398.0
# 5     1163.0             170.0        0.0              12.0     1163.0
#
#    B23006026, Error  B23006027  B23006027, Error  B23006028  B23006028, Error  \
# 1             138.0      711.0             134.0       36.0              35.0
# 2             347.0     1641.0             347.0        0.0              12.0
# 3             306.0     1790.0             316.0       79.0             101.0
# 4             290.0     1259.0             264.0      139.0             104.0
# 5             170.0     1145.0             168.0       18.0              21.0
#
#    B23006029  B23006029, Error  \
# 1      120.0              59.0
# 2      236.0             145.0
# 3      219.0              92.0
# 4       81.0              74.0
# 5      144.0              66.0
#
#                                             geometry
# 1  MULTIPOLYGON (((-117.17887 32.75765, -117.1779...
# 2  MULTIPOLYGON (((-117.18404 32.74571, -117.1838...
# 3  MULTIPOLYGON (((-117.16864 32.74897, -117.1684...
# 4  MULTIPOLYGON (((-117.17087 32.75865, -117.1701...
# 5  MULTIPOLYGON (((-117.16128 32.75907, -117.1606...

# %%
list(edu)
# Out:
# ['geoid',
#  'name',
#  'B23006001',
#  'B23006001, Error',
#  'B23006002',
#  'B23006002, Error',
#  'B23006003',
#  'B23006003, Error',
#  'B23006004',
#  'B23006004, Error',
#  'B23006005',
#  'B23006005, Error',
#  'B23006006',
#  'B23006006, Error',
#  'B23006007',
#  'B23006007, Error',
#  'B23006008',
#  'B23006008, Error',
#  'B23006009',
#  'B23006009, Error',
#  'B23006010',
#  'B23006010, Error',
#  'B23006011',
#  'B23006011, Error',
#  'B23006012',
#  'B23006012, Error',
#  'B23006013',
#  'B23006013, Error',
#  'B23006014',
#  'B23006014, Error',
#  'B23006015',
#  'B23006015, Error',
#  'B23006016',
#  'B23006016, Error',
#  'B23006017',
#  'B23006017, Error',
#  'B23006018',
#  'B23006018, Error',
#  'B23006019',
#  'B23006019, Error',
#  'B23006020',
#  'B23006020, Error',
#  'B23006021',
#  'B23006021, Error',
#  'B23006022',
#  'B23006022, Error',
#  'B23006023',
#  'B23006023, Error',
#  'B23006024',
#  'B23006024, Error',
#  'B23006025',
#  'B23006025, Error',
#  'B23006026',
#  'B23006026, Error',
#  'B23006027',
#  'B23006027, Error',
#  'B23006028',
#  'B23006028, Error',
#  'B23006029',
#  'B23006029, Error',
#  'geometry']

# %%
# columns to keep
columns_to_keep = ['geoid',
 'name',
 'B23006001',
 'B23006002',
 'B23006009',
 'B23006016',
 'B23006023',
 'B23006024',
 'B23006025',
 'B23006026',
 'B23006027',
 'B23006028',
 'B23006029',
 'geometry']

# %%
# redefine edu with only columns to keep
edu = edu[columns_to_keep]

# %%
# check the slimmed down gdf
edu.head()
# Out:
#                 geoid                              name  B23006001  B23006002  \
# 1  14000US06073000201  Census Tract 2.01, San Diego, CA     1025.0        0.0
# 2  14000US06073000202  Census Tract 2.02, San Diego, CA     2972.0       43.0
# 3  14000US06073000300     Census Tract 3, San Diego, CA     3359.0       79.0
# 4  14000US06073000400     Census Tract 4, San Diego, CA     2720.0       55.0
# 5  14000US06073000500     Census Tract 5, San Diego, CA     2195.0       43.0
#
#    B23006009  B23006016  B23006023  B23006024  B23006025  B23006026  \
# 1       53.0      105.0      867.0      747.0        0.0      747.0
# 2      224.0      778.0     1927.0     1691.0       50.0     1641.0
# 3      171.0     1021.0     2088.0     1869.0        0.0     1869.0
# 4      257.0      902.0     1506.0     1425.0       27.0     1398.0
# 5      219.0      626.0     1307.0     1163.0        0.0     1163.0
#
#    B23006027  B23006028  B23006029  \
# 1      711.0       36.0      120.0
# 2     1641.0        0.0      236.0
# 3     1790.0       79.0      219.0
# 4     1259.0      139.0       81.0
# 5     1145.0       18.0      144.0
#
#                                             geometry
# 1  MULTIPOLYGON (((-117.17887 32.75765, -117.1779...
# 2  MULTIPOLYGON (((-117.18404 32.74571, -117.1838...
# 3  MULTIPOLYGON (((-117.16864 32.74897, -117.1684...
# 4  MULTIPOLYGON (((-117.17087 32.75865, -117.1701...
# 5  MULTIPOLYGON (((-117.16128 32.75907, -117.1606...

# %%
list(edu)
# Out:
# ['geoid',
#  'name',
#  'B23006001',
#  'B23006002',
#  'B23006009',
#  'B23006016',
#  'B23006023',
#  'B23006024',
#  'B23006025',
#  'B23006026',
#  'B23006027',
#  'B23006028',
#  'B23006029',
#  'geometry']

# %%
edu.columns = ['geoid',
 'name',
 'Total',
 'Less than HS graduate',
 'HS Graduate',
 'Some College or Associates Degree',
 'Bachelors degree or Higher',
 'In Labor Force',
 'In Armed Forces',
 'Civillian',
 'Employed',
 'Unemployed',
 'Not in Labor Force',
 'geometry']

# %%
edu.head()
# Out:
#                 geoid                              name   Total  \
# 1  14000US06073000201  Census Tract 2.01, San Diego, CA  1025.0
# 2  14000US06073000202  Census Tract 2.02, San Diego, CA  2972.0
# 3  14000US06073000300     Census Tract 3, San Diego, CA  3359.0
# 4  14000US06073000400     Census Tract 4, San Diego, CA  2720.0
# 5  14000US06073000500     Census Tract 5, San Diego, CA  2195.0
#
#    Less than HS graduate  HS Graduate  Some College or Associates Degree  \
# 1                    0.0         53.0                              105.0
# 2                   43.0        224.0                              778.0
# 3                   79.0        171.0                             1021.0
# 4                   55.0        257.0                              902.0
# 5                   43.0        219.0                              626.0
#
#    Bachelors degree or Higher  In Labor Force  In Armed Forces  Civillian  \
# 1                       867.0           747.0              0.0      747.0
# 2                      1927.0          1691.0             50.0     1641.0
# 3                      2088.0          1869.0              0.0     1869.0
# 4                      1506.0          1425.0             27.0     1398.0
# 5                      1307.0          1163.0              0.0     1163.0
#
#    Employed  Unemployed  Not in Labor Force  \
# 1     711.0        36.0               120.0
# 2    1641.0         0.0               236.0
# 3    1790.0        79.0               219.0
# 4    1259.0       139.0                81.0
# 5    1145.0        18.0               144.0
#
#                                             geometry
# 1  MULTIPOLYGON (((-117.17887 32.75765, -117.1779...
# 2  MULTIPOLYGON (((-117.18404 32.74571, -117.1838...
# 3  MULTIPOLYGON (((-117.16864 32.74897, -117.1684...
# 4  MULTIPOLYGON (((-117.17087 32.75865, -117.1701...
# 5  MULTIPOLYGON (((-117.16128 32.75907, -117.1606...

# %%
# get a random record
random_tract = edu.sample()
random_tract
# Out:
#                   geoid                                name   Total  \
# 501  14000US06073018610  Census Tract 186.10, San Diego, CA  4045.0
#
#      Less than HS graduate  HS Graduate  Some College or Associates Degree  \
# 501                 1065.0        918.0                             1275.0
#
#      Bachelors degree or Higher  In Labor Force  In Armed Forces  Civillian  \
# 501                       787.0           653.0             24.0      629.0
#
#      Employed  Unemployed  Not in Labor Force  \
# 501     618.0        11.0               134.0
#
#                                               geometry
# 501  MULTIPOLYGON (((-117.31196 33.25773, -117.3117...

# %%
# example usage of iloc to get the total population of our random record
# "for the 0th record, get the value in the Total column"
random_tract.iloc[0]['Total']
# Out:
# 4045.0

# %%
# print this out in plain english
print('Total population: ' + str(random_tract.iloc[0]['Total']))
# Out:
# Total population: 4045.0

# %%
# Less than HS degree plus all the HS degree and higher categories
print(random_tract.iloc[0]['Less than HS graduate'] + 
      random_tract.iloc[0]['HS Graduate'] + 
      random_tract.iloc[0]['Some College or Associates Degree'] + 
      random_tract.iloc[0]['Bachelors degree or Higher'])
# Out:
# 4045.0

# %%
# access a single column like df['col_name']
edu['Total'].head()
# Out:
# 1    1025.0
# 2    2972.0
# 3    3359.0
# 4    2720.0
# 5    2195.0
# Name: Total, dtype: float64

# %%
# What is the mean?
edu['Total'].mean()
# Out:
# 2856.5406698564593

# %%
# What is the median?
edu['Total'].median()
# Out:
# 2663.0

# %%
#  get some stats
edu['Total'].describe()
# Out:
# count      627.00000
# mean      2856.54067
# std       1505.11987
# min          0.00000
# 25%       1967.50000
# 50%       2663.00000
# 75%       3449.00000
# max      16520.00000
# Name: Total, dtype: float64

# %%
# plot it as a historgram with 50 bins
edu['Total'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
edu_sorted = edu.sort_values(by='Total',ascending = False)

# %%
# display the data, but just a few columns to keep it clean
edu_sorted[['geoid','Total']].head(10)
# Out:
#                   geoid    Total
# 307  14000US06073013310  16520.0
# 425  14000US06073017030  12867.0
# 248  14000US06073010014  12245.0
# 311  14000US06073013314  11866.0
# 310  14000US06073013313  10751.0
# 506  14000US06073018700  10254.0
# 155  14000US06073008333   9502.0
# 564  14000US06073020027   8618.0
# 427  14000US06073017032   8236.0
# 550  14000US06073020013   7874.0

# %%
# plot it
edu_sorted.head(10).plot()
# Out:
# <AxesSubplot:>

# %%
# Make it prettier
edu_sorted.head(100).plot(figsize=(10,10),column='Total',legend=True)
# Out:
# <AxesSubplot:>

# %%
# subset the data so that we can see the data per row... 
# in other words, this syntax is asking to "show me the values in my dataframe that match this filter
edu[edu['Total']==0]
# Out:
#                   geoid                               name  Total  \
# 110  14000US06073006200     Census Tract 62, San Diego, CA    0.0
# 238  14000US06073009902  Census Tract 99.02, San Diego, CA    0.0
# 627  14000US06073990100   Census Tract 9901, San Diego, CA    0.0
#
#      Less than HS graduate  HS Graduate  Some College or Associates Degree  \
# 110                    0.0          0.0                                0.0
# 238                    0.0          0.0                                0.0
# 627                    0.0          0.0                                0.0
#
#      Bachelors degree or Higher  In Labor Force  In Armed Forces  Civillian  \
# 110                         0.0             0.0              0.0        0.0
# 238                         0.0             0.0              0.0        0.0
# 627                         0.0             0.0              0.0        0.0
#
#      Employed  Unemployed  Not in Labor Force  \
# 110       0.0         0.0                 0.0
# 238       0.0         0.0                 0.0
# 627       0.0         0.0                 0.0
#
#                                               geometry
# 110  MULTIPOLYGON (((-117.21404 32.72445, -117.2140...
# 238  MULTIPOLYGON (((-117.23991 32.69564, -117.2398...
# 627  MULTIPOLYGON (((-117.61104 33.33413, -117.6086...

# %%
# create a new variable for census tracts with zero pop
edu_no_pop = edu[edu['Total']==0]

# %%
# how many records?
print('There are ' + str(len(edu_no_pop)) + ' census tracts with no people in them')
# Out:
# There are 3 census tracts with no people in them

# %%
# display it
edu_no_pop[['geoid','Total']]
# Out:
#                   geoid  Total
# 110  14000US06073006200    0.0
# 238  14000US06073009902    0.0
# 627  14000US06073990100    0.0

# %%
# output columns
list(edu)
# Out:
# ['geoid',
#  'name',
#  'Total',
#  'Less than HS graduate',
#  'HS Graduate',
#  'Some College or Associates Degree',
#  'Bachelors degree or Higher',
#  'In Labor Force',
#  'In Armed Forces',
#  'Civillian',
#  'Employed',
#  'Unemployed',
#  'Not in Labor Force',
#  'geometry']

# %%
# create a new column, and populate it with normalized data to get the percent of total value
edu['Percent Less than HS graduate'] = edu['Less than HS graduate']/edu['Total']*100
edu['Percent HS Graduate'] = edu['HS Graduate']/edu['Total']*100
edu['Percent Some College or Associates Degree'] = edu['Some College or Associates Degree']/edu['Total']*100
edu['Percent Bachelors degree or Higher'] = edu['Bachelors degree or Higher']/edu['Total']*100

# %%
edu.sample(5)
# Out:
#                   geoid                                name   Total  \
# 28   14000US06073002402   Census Tract 24.02, San Diego, CA  2942.0
# 415  14000US06073017009  Census Tract 170.09, San Diego, CA  2552.0
# 534  14000US06073019502  Census Tract 195.02, San Diego, CA  2891.0
# 229  14000US06073009703   Census Tract 97.03, San Diego, CA  1914.0
# 607  14000US06073020811  Census Tract 208.11, San Diego, CA  3193.0
#
#      Less than HS graduate  HS Graduate  Some College or Associates Degree  \
# 28                  1486.0        531.0                              717.0
# 415                  217.0        483.0                              901.0
# 534                 1487.0        648.0                              585.0
# 229                   85.0        242.0                              508.0
# 607                   70.0        753.0                             1297.0
#
#      Bachelors degree or Higher  In Labor Force  In Armed Forces  Civillian  \
# 28                        208.0           185.0              0.0      185.0
# 415                       951.0           860.0              0.0      860.0
# 534                       171.0           110.0              0.0      110.0
# 229                      1079.0           997.0              9.0      988.0
# 607                      1073.0           856.0              0.0      856.0
#
#      Employed  Unemployed  Not in Labor Force  \
# 28      164.0        21.0                23.0
# 415     840.0        20.0                91.0
# 534     103.0         7.0                61.0
# 229     959.0        29.0                82.0
# 607     833.0        23.0               217.0
#
#                                               geometry  \
# 28   MULTIPOLYGON (((-117.11036 32.74412, -117.1099...
# 415  MULTIPOLYGON (((-117.03666 32.95663, -117.0366...
# 534  MULTIPOLYGON (((-117.24498 33.20459, -117.2449...
# 229  MULTIPOLYGON (((-117.08561 32.78470, -117.0848...
# 607  MULTIPOLYGON (((-116.84455 32.99800, -116.8443...
#
#      Percent Less than HS graduate  Percent HS Graduate  \
# 28                       50.509857            18.048946
# 415                       8.503135            18.926332
# 534                      51.435489            22.414389
# 229                       4.440961            12.643678
# 607                       2.192296            23.582837
#
#      Percent Some College or Associates Degree  \
# 28                                   24.371176
# 415                                  35.305643
# 534                                  20.235213
# 229                                  26.541275
# 607                                  40.620106
#
#      Percent Bachelors degree or Higher
# 28                             7.070020
# 415                           37.264890
# 534                            5.914908
# 229                           56.374086
# 607                           33.604760

# %%
# the remaining columns
edu['Percent In Labor Force'] = edu['In Labor Force']/edu['Total']*100
edu['Percent In Armed Forces'] = edu['In Armed Forces']/edu['Total']*100
edu['Percent Civillian'] = edu['Civillian']/edu['Total']*100
edu['Percent Employed'] = edu['Employed']/edu['Total']*100
edu['Percent Unmployed'] = edu['Unemployed']/edu['Total']*100
edu['Percent Not in Labor Force'] = edu['Not in Labor Force']/edu['Total']*100

# %%
# function to plot percentages of education
def map_percent(column_name, scheme):
    edu.plot(figsize=(12,10),
             column=column_name,
             legend=True,
             scheme=scheme)
    plt.title(column_name)

# %%
# recreating map from cell below to ensure map_percent function works
map_percent(column_name='Percent Less than HS graduate', scheme='NaturalBreaks')

# %%
# columns that we are going to map
loop_columns = ['Percent Less than HS graduate', 'Percent HS Graduate', 
                'Percent Some College or Associates Degree', 'Percent Bachelors degree or Higher']

# loop through columns that we want to map and call the function map_percent to output the map 
for column in loop_columns:
    map_percent(column, scheme = 'NaturalBreaks')

# %%
# create the 1x2 subplots
fig, axs = plt.subplots(1, 2, figsize=(15, 12))

# name each subplot
ax1, ax2 = axs

# percent Less than HS graduate map on the left
edu.plot(column='Percent Less than HS graduate', 
            cmap='RdYlGn_r', 
            scheme='quantiles',
            k=5, 
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

ax1.axis("off")
ax1.set_title("Percent Less than HS graduate")

# percent Bachelors degree or higher map on the right
edu.plot(column='Percent Bachelors degree or Higher', 
            cmap='RdYlGn_r', 
            scheme='quantiles',
            k=5, 
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, # this assigns the map to the subplot
            legend=True
           )

ax2.axis("off")
ax2.set_title("Percent Bachelors degree or Higher")
# Out:
# Text(0.5, 1.0, 'Percent Bachelors degree or Higher')

# %%
edu[edu['Percent Less than HS graduate'] >50]
# Out:
#                   geoid                                name   Total  \
# 28   14000US06073002402   Census Tract 24.02, San Diego, CA  2942.0
# 534  14000US06073019502  Census Tract 195.02, San Diego, CA  2891.0
#
#      Less than HS graduate  HS Graduate  Some College or Associates Degree  \
# 28                  1486.0        531.0                              717.0
# 534                 1487.0        648.0                              585.0
#
#      Bachelors degree or Higher  In Labor Force  In Armed Forces  Civillian  \
# 28                        208.0           185.0              0.0      185.0
# 534                       171.0           110.0              0.0      110.0
#
#      Employed  Unemployed  Not in Labor Force  \
# 28      164.0        21.0                23.0
# 534     103.0         7.0                61.0
#
#                                               geometry  \
# 28   MULTIPOLYGON (((-117.11036 32.74412, -117.1099...
# 534  MULTIPOLYGON (((-117.24498 33.20459, -117.2449...
#
#      Percent Less than HS graduate  Percent HS Graduate  \
# 28                       50.509857            18.048946
# 534                      51.435489            22.414389
#
#      Percent Some College or Associates Degree  \
# 28                                   24.371176
# 534                                  20.235213
#
#      Percent Bachelors degree or Higher  Percent In Labor Force  \
# 28                             7.070020                6.288239
# 534                            5.914908                3.804912
#
#      Percent In Armed Forces  Percent Civillian  Percent Employed  \
# 28                       0.0           6.288239          5.574439
# 534                      0.0           3.804912          3.562781
#
#      Percent Unmployed  Percent Not in Labor Force
# 28            0.713800                    0.781781
# 534           0.242131                    2.109997

# %%
# reproject to Web Mercator
gdf_web_mercator = edu.to_crs(epsg=3857)

# %%
# use subplots that make it easier to create multiple layered maps
fig, ax = plt.subplots(figsize=(15, 15))

# add the layer with ax=ax in the argument 
gdf_web_mercator[gdf_web_mercator['Percent Less than HS graduate'] > 50].plot(ax=ax, alpha=0.8)

# turn the axis off
ax.axis('off')

# set a title
ax.set_title('Census Tracts with more than 50% Less than High School graduate Population',fontsize=16)

# add a basemap
ctx.add_basemap(ax)
